# %%
# project: p7
# submitter: csharma4@wisc.edu
# partner: None
# hours: 8

# %%
import csv
import datetime

# %%
def process_csv(filename):
    example_file = open(filename, encoding="utf-8")
    example_reader = csv.reader(example_file)
    example_data = list(example_reader)
    example_file.close()
    return example_data

# %%
# Use process_csv to pull out the header and data rows
csv_rows = process_csv("vaccinations.csv")

# Use indexing to extract the first inner list
csv_header = csv_rows[0]

# Use slicing to extract all the inner lists, except the first one
csv_data = csv_rows[1:]

# %%
def cell(row_idx, col_name):
    """
    Returns the data value (cell) corresponding to the row index and 
    the column name of a CSV file.
    """
    col_idx = csv_header.index(col_name)
    val = csv_data[row_idx][col_idx]
    if val == "": # this is how we handle a missing value in the dataset
        return None
    # TODO: make sure the function returns val with the appropriate type
    col_idx = csv_header.index(col_name)
    if col_name == 'date' or col_name == 'country':
        val = csv_data[row_idx][col_idx]
    else:val = int(csv_data[row_idx][col_idx])
    return val

# %%
#Q1: What dates are mentioned in the dataset?
dates = []
for i in range(len(csv_rows)-1):
    date = cell(i,'date')
    dates.append(date)
    dateSet = set(dates)
    dates = list(dateSet)
    dates.sort()
    dates.reverse()
dates
# Out:
# ['01/31/2022',
#  '01/30/2022',
#  '01/29/2022',
#  '01/28/2022',
#  '01/27/2022',
#  '01/26/2022',
#  '01/25/2022']

# %%
#Q2: What countries are listed in the dataset?
countries = []
for i in range(len(csv_rows)-1):
    country = cell(i,'country')
    countries.append(country)
    countrySet = set(countries)
    countries = list(countrySet)
countries.sort()
countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'England',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faeroe Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
# ...

# %%
#Q3: What is the population of each country in the dataset?
populationData = {}
for i in range(len(csv_rows)-1):
    country = cell(i,'country')
    population = cell(i,'population')
    if country not in populationData:
        populationData[country] = None
    if populationData[country] == None:
        populationData[country] = population
        if population == None:
             populationData[country] = None
populationData
# Out:
# {'Afghanistan': 39822425,
#  'Albania': 2873046,
#  'Angola': 33934485,
#  'Anguilla': 15126,
#  'Antigua and Barbuda': 98726,
#  'Argentina': 45605836,
#  'Armenia': 2968277,
#  'Aruba': 107194,
#  'Austria': 9043061,
#  'Azerbaijan': 10222990,
#  'Bahamas': 396909,
#  'Bahrain': 1748265,
#  'Bangladesh': 166312179,
#  'Barbados': 287709,
#  'Belarus': 9442839,
#  'Belgium': 11632221,
#  'Belize': 404916,
#  'Bermuda': 62094,
#  'Bhutan': 779889,
#  'Bolivia': 11832385,
#  'Bosnia and Herzegovina': 3263734,
#  'Brazil': 213992450,
#  'British Virgin Islands': 30423,
#  'Brunei': 441538,
#  'Bulgaria': 6896487,
#  'Cambodia': 16946049,
#  'Canada': 38067582,
#  'Cayman Islands': 66498,
#  'Central African Republic': 4921767,
#  'Chad': 16903319,
#  'Chile': 19212518,
#  'China': 1444229881,
#  'Colombia': 51267219,
#  'Comoros': 888427,
#  'Costa Rica': 5138966,
#  "Cote d'Ivoire": 27053133,
#  'Croatia': 4081748,
#  'Cuba': 11317506,
#  'Curacao': 164798,
#  'Cyprus': 895987,
# ...

# %%
#Q4: How many countries have an entry for daily vaccination on Jan 28, 2022?
count = 0
for i in range(len(csv_rows)-1):
    if cell(i,'date') == '01/28/2022':
        if cell(i,'daily_vaccinations') != None:
            count += 1
count
# Out:
# 80

# %%
def daily_vaccinations_on(search_date):
    '''return a dictionary mapping each country to
    the number of daily vaccinations on the given date;
    if data is missing, the value for that country is None'''
    vaccinations = {}
    for i in range(len(csv_rows)-1):
        country = cell(i,'country')
        dailyVax = cell(i,'daily_vaccinations')
        date = cell(i,'date')
        if country not in vaccinations:
            vaccinations[country] = None
        if vaccinations[country] == None and date == search_date:
            vaccinations[country] = dailyVax
            if dailyVax == None:
                vaccinations[country] = None
    return vaccinations

# %%
#Q5: For each country, how many vaccinations were given on Jan 31, 2022?
daily_vaccinations_on('01/31/2022')
# Out:
# {'Afghanistan': None,
#  'Albania': None,
#  'Angola': None,
#  'Anguilla': None,
#  'Antigua and Barbuda': None,
#  'Argentina': 363848,
#  'Armenia': None,
#  'Aruba': None,
#  'Austria': None,
#  'Azerbaijan': 18,
#  'Bahamas': None,
#  'Bahrain': 2272,
#  'Bangladesh': None,
#  'Barbados': None,
#  'Belarus': None,
#  'Belgium': 24295,
#  'Belize': None,
#  'Bermuda': None,
#  'Bhutan': None,
#  'Bolivia': 66683,
#  'Bosnia and Herzegovina': None,
#  'Brazil': 1193530,
#  'British Virgin Islands': None,
#  'Brunei': None,
#  'Bulgaria': 7958,
#  'Cambodia': 23460,
#  'Canada': 328723,
#  'Cayman Islands': None,
#  'Central African Republic': None,
#  'Chad': None,
#  'Chile': 83517,
#  'China': 334000,
#  'Colombia': 227734,
#  'Comoros': None,
#  'Costa Rica': None,
#  "Cote d'Ivoire": None,
#  'Croatia': 5165,
#  'Cuba': 19966,
#  'Curacao': 262,
#  'Cyprus': None,
#  'Czechia': 30168,
#  'Democratic Republic of Congo': None,
#  'Denmark': 9331,
#  'Djibouti': None,
# ...

# %%
#Q6: For each country, what is the sum of the vaccinations given on all of the dates mentioned in the dataset?
vaxSum = {}
for country in countries:
    sumVax = 0
    for date in dates:
        if daily_vaccinations_on(date)[country] != None:
            sumVax += daily_vaccinations_on(date)[country]
    if country not in vaxSum:
        vaxSum[country] = None
    if vaxSum[country] == None:
        vaxSum[country] = sumVax
    if vaxSum[country] == 0:
        vaxSum[country] = None
vaxSum
# Out:
# {'Afghanistan': 6868,
#  'Albania': None,
#  'Angola': None,
#  'Anguilla': None,
#  'Antigua and Barbuda': None,
#  'Argentina': 1424935,
#  'Armenia': None,
#  'Aruba': 109,
#  'Austria': None,
#  'Azerbaijan': 186924,
#  'Bahamas': None,
#  'Bahrain': 24377,
#  'Bangladesh': 2534125,
#  'Barbados': 655,
#  'Belarus': None,
#  'Belgium': 271202,
#  'Belize': None,
#  'Bermuda': None,
#  'Bhutan': None,
#  'Bolivia': 330401,
#  'Bosnia and Herzegovina': None,
#  'Brazil': 7625078,
#  'British Virgin Islands': None,
#  'Brunei': None,
#  'Bulgaria': 61239,
#  'Cambodia': 461795,
#  'Canada': 1754870,
#  'Cayman Islands': None,
#  'Central African Republic': None,
#  'Chad': None,
#  'Chile': 401911,
#  'China': 27073000,
#  'Colombia': 1082431,
#  'Comoros': None,
#  'Costa Rica': None,
#  "Cote d'Ivoire": None,
#  'Croatia': 48491,
#  'Cuba': 523203,
#  'Curacao': 1103,
#  'Cyprus': 2596,
#  'Czechia': 220159,
#  'Democratic Republic of Congo': None,
#  'Denmark': 76940,
# ...

# %%
#Q7: Which country completed the most number of vaccinations during the dates mentioned in the dataset?
max = 0
for country in countries:
    if vaxSum[country] != None:
        if vaxSum[country] > max:
            max = vaxSum[country]
            nation = country
nation
# Out:
# 'India'

# %%
#Q8: How many vaccinations (across the world) were given on each date?
total = {}
for date in dates:
    sum = 0
    for country in countries:
        if daily_vaccinations_on(date)[country] != None:
            sum += daily_vaccinations_on(date)[country]
    if date not in total:
        total[date] = None
    if total[date] == None:
        total[date] = sum
total
# Out:
# {'01/31/2022': 15251126,
#  '01/30/2022': 13056961,
#  '01/29/2022': 14844495,
#  '01/28/2022': 19825492,
#  '01/27/2022': 19551593,
#  '01/26/2022': 22075204,
#  '01/25/2022': 21919087}

# %%
#Q9: For each country in the dataset, when is the last date for which we have information about the number of fully vaccinated people?
latest = {}
for i in range(len(csv_rows)-1):
    country = cell(i,'country')
    people = cell(i,'people_fully_vaccinated')
    for date in dates:
            if country not in latest:
                latest[country] = None
            if latest[country] == None:
                latest[country] = date
latest
# Out:
# {'Afghanistan': '01/31/2022',
#  'Albania': '01/31/2022',
#  'Angola': '01/31/2022',
#  'Anguilla': '01/31/2022',
#  'Antigua and Barbuda': '01/31/2022',
#  'Argentina': '01/31/2022',
#  'Armenia': '01/31/2022',
#  'Aruba': '01/31/2022',
#  'Austria': '01/31/2022',
#  'Azerbaijan': '01/31/2022',
#  'Bahamas': '01/31/2022',
#  'Bahrain': '01/31/2022',
#  'Bangladesh': '01/31/2022',
#  'Barbados': '01/31/2022',
#  'Belarus': '01/31/2022',
#  'Belgium': '01/31/2022',
#  'Belize': '01/31/2022',
#  'Bermuda': '01/31/2022',
#  'Bhutan': '01/31/2022',
#  'Bolivia': '01/31/2022',
#  'Bosnia and Herzegovina': '01/31/2022',
#  'Brazil': '01/31/2022',
#  'British Virgin Islands': '01/31/2022',
#  'Brunei': '01/31/2022',
#  'Bulgaria': '01/31/2022',
#  'Cambodia': '01/31/2022',
#  'Canada': '01/31/2022',
#  'Cayman Islands': '01/31/2022',
#  'Central African Republic': '01/31/2022',
#  'Chad': '01/31/2022',
#  'Chile': '01/31/2022',
#  'China': '01/31/2022',
#  'Colombia': '01/31/2022',
# ...

# %%
def get_number_of_days(start_date, end_date):
    """Gets the number of days between the start_date and end_date"""
    # The second argument is a format string to tell the function how to process the date string
    day1 = datetime.datetime.strptime(start_date, '%m/%d/%Y') 
    day2 = datetime.datetime.strptime(end_date, '%m/%d/%Y')
    delta = day2 - day1
    return delta.days

# %%
def most_recent_total(col_name, given_date):
    '''return a dictionary mapping each country to the most recent column value in the data 
    available by the given date; if no data is available, the value is None.'''
    country_info = {}
    for row_idx in range(len(csv_rows)-1):
        country = cell(row_idx,'country')
        date = cell(row_idx,'date')
        col_value = cell(row_idx,col_name) #the value of this row in the column indicated by col_name
        if country not in country_info:
            country_info[country] = None #what should be the default, placeholder value?
        if country_info[country] == None and get_number_of_days(date,given_date) <= 0 and col_value != None: # Make sure the col_value is not missing AND Check if the date is on or before given_date:
            country_info[country] = col_value
        if country_info[country] == None:
            country_info[country] = None
    return country_info

# %%
#Q10: How many people were estimated to be fully vaccinated in each country, as of 31 Jan 2022?
vaxData = most_recent_total('people_fully_vaccinated',date)
vaxData
# Out:
# {'Afghanistan': 3866279,
#  'Albania': 1111520,
#  'Angola': 4731866,
#  'Anguilla': 9336,
#  'Antigua and Barbuda': 60358,
#  'Argentina': 34414875,
#  'Armenia': 837694,
#  'Aruba': 79673,
#  'Austria': 6470286,
#  'Azerbaijan': 4732155,
#  'Bahamas': 151520,
#  'Bahrain': 1192261,
#  'Bangladesh': 59108539,
#  'Barbados': 146699,
#  'Belarus': 4233740,
#  'Belgium': 8858389,
#  'Belize': 203237,
#  'Bermuda': 45863,
#  'Bhutan': 570751,
#  'Bolivia': 5112190,
#  'Bosnia and Herzegovina': 842954,
#  'Brazil': 149165531,
#  'British Virgin Islands': 17215,
#  'Brunei': 403385,
#  'Bulgaria': 1980511,
#  'Cambodia': 13743612,
#  'Canada': 29903275,
#  'Cayman Islands': 57473,
#  'Central African Republic': 549473,
#  'Chad': 136143,
#  'Chile': 16894804,
#  'China': 1227387000,
#  'Colombia': 31062511,
#  'Comoros': 256898,
#  'Costa Rica': 3654209,
#  "Cote d'Ivoire": 2382472,
#  'Croatia': 2199638,
#  'Cuba': 9811501,
#  'Curacao': 97494,
#  'Cyprus': 626637,
# ...

# %%
#Q11: Among countries with population less than 100 million, which country is estimated to have had the highest number of fully vaccinated people by 31 Jan 2022?
max = 0
for country in countries:
    if populationData[country] != None and vaxData[country] != None:
        if populationData[country] < 100000000:
            if vaxData[country] > max:
                max = vaxData[country]
                nation = country
nation
# Out:
# 'Germany'

# %%
vaccination_stats = {}

for date in dates:
    daily_vax_dict = daily_vaccinations_on(date) # a dict mapping each country to number of daily_vaccinations on date
    
    total_vax_dict = most_recent_total('total_vaccinations',date) # a dict mapping each country to the most recent number of total_vaccinations on date
          
    people_vax_dict = most_recent_total('people_vaccinated',date) # a dict mapping each country to the most recent number of people_vaccinated on date
      
    fully_vax_dict = most_recent_total('people_fully_vaccinated',date) # a dict mapping each country to most recent number of people_fully_vaccinated on date
            
    total_booster_dict = most_recent_total('total_boosters',date) # a dict mapping each country to most recent number of total_boosters on date
        
    for country in countries:                                                 
        if country not in vaccination_stats:
            vaccination_stats[country] = {}
        vaccination_stats[country][date] = {}
        vaccination_stats[country][date]['country'] = country
        vaccination_stats[country][date]['date'] = date
        # TODO: fill in the rest of the dict to match the example above
        vaccination_stats[country][date]['daily_vaccinations'] = daily_vax_dict[country]
        vaccination_stats[country][date]['total_vaccinations'] = total_vax_dict[country]
        vaccination_stats[country][date]['people_vaccinated'] = people_vax_dict[country]
        vaccination_stats[country][date]['people_fully_vaccinated'] = fully_vax_dict[country]
        vaccination_stats[country][date]['total_boosters'] = total_booster_dict[country]
        vaccination_stats[country][date]['population'] = populationData[country]

# %%
#Q12: What are the vaccination records for the United States on 31 Jan 2022?
vaccination_stats['United States']['01/31/2022']
# Out:
# {'country': 'United States',
#  'date': '01/31/2022',
#  'daily_vaccinations': 600555,
#  'total_vaccinations': 542867964,
#  'people_vaccinated': 250964826,
#  'people_fully_vaccinated': 211957212,
#  'total_boosters': 89474239,
#  'population': 332009030}

# %%
#Q13: What are the vaccination records for Argentina on 25 Jan 2022?
vaccination_stats['Argentina']['01/25/2022']
# Out:
# {'country': 'Argentina',
#  'date': '01/25/2022',
#  'daily_vaccinations': None,
#  'total_vaccinations': 85763224,
#  'people_vaccinated': 39445508,
#  'people_fully_vaccinated': 34414875,
#  'total_boosters': 11656958,
#  'population': 45605836}

# %%
#Q14: What are the vaccination records for Belgium on 27 Jan 2022?
vaccination_stats['Belgium']['01/27/2022']
# Out:
# {'country': 'Belgium',
#  'date': '01/27/2022',
#  'daily_vaccinations': 42940,
#  'total_vaccinations': 24059785,
#  'people_vaccinated': 9128092,
#  'people_fully_vaccinated': 8863018,
#  'total_boosters': 6495754,
#  'population': 11632221}

# %%
#Q15: What are the vaccination records for the country with the highest population in the dataset on 29 Jan 2022?
max = 0
for country in populationData:
    if populationData[country] != None:
        if populationData[country] > max:
            max = populationData[country]
            nation = country
vaccination_stats[nation]['01/29/2022']
# Out:
# {'country': 'China',
#  'date': '01/29/2022',
#  'daily_vaccinations': 3722000,
#  'total_vaccinations': 2997884000,
#  'people_vaccinated': None,
#  'people_fully_vaccinated': 1227387000,
#  'total_boosters': None,
#  'population': 1444229881}

# %%
#Q16: What is the estimated ratio of people who have been partly vaccinated to people who have been fully vaccinated in each country, as of Jan 31, 2022?
ratioVax = {}
date = '01/25/2022'
for country in countries:
    if vaccination_stats[country][date]['people_vaccinated']!= None and vaccination_stats[country][date]['people_fully_vaccinated'] != None: 
        num  = vaccination_stats[country][date]['people_fully_vaccinated']
        den = vaccination_stats[country][date]['people_vaccinated']
    ratio = (den-num)/num
    ratioVax[country] = None
    if ratioVax[country] == None:
        ratioVax[country] = ratio
    if ratioVax[country] == None:
        ratioVax[country] = None
ratioVax
# Out:
# {'Afghanistan': 0.16685112481535863,
#  'Albania': 0.088635382179358,
#  'Angola': 1.05279397176505,
#  'Anguilla': 0.09179520137103685,
#  'Antigua and Barbuda': 0.047036018423407,
#  'Argentina': 0.14617612297008198,
#  'Armenia': 0.2482016106119896,
#  'Aruba': 0.0849848756793393,
#  'Austria': 0.045065395872763585,
#  'Azerbaijan': 0.10253785009155449,
#  'Bahamas': 0.05929910242872228,
#  'Bahrain': 0.022649403108883037,
#  'Bangladesh': 0.6021931450547272,
#  'Barbados': 0.07868492627761607,
#  'Belarus': 0.07868492627761607,
#  'Belgium': 0.02811086756293949,
#  'Belize': 0.14405841456034088,
#  'Bermuda': 0.01814098510782112,
#  'Bhutan': 0.04069900884974358,
#  'Bolivia': 0.30043171321879664,
#  'Bosnia and Herzegovina': 0.11485917381019604,
#  'Brazil': 0.12992920596380944,
#  'British Virgin Islands': 0.08934069125762417,
#  'Brunei': 0.009065780829728424,
#  'Bulgaria': 0.009065780829728424,
#  'Cambodia': 0.04356496676419561,
#  'Canada': 0.07802011652569828,
# ...

# %%
#Q17: Which country has administered the most number of booster shots as of Jan 31, 2022
max = 0
for country in countries:
    for date in dates:
        if vaccination_stats[country][date]['total_boosters'] != None and vaccination_stats[country][date]['total_boosters'] > max:
            max += vaccination_stats[country][date]['total_boosters']
            nation = country
nation
# Out:
# 'United States'

# %%
#Q18: Which country is estimated to have administered the most number of booster shots per capita, as of 25 Jan 2022?
max = 0
for country in countries:
    boosters = 0
    if vaccination_stats[country]['01/31/2022']['total_boosters'] != None:
        boosters = int(vaccination_stats[country]['01/31/2022']['total_boosters'])
        if boosters/populationData[country] > max:
            max = boosters/populationData[country]
            nation = country
nation
# Out:
# 'Chile'

# %%
#Q19: What is the percentage of population boosted by Jan 31, 2022 of each country in the dataset?
perPop = {}
for country in countries:
    if populationData[country] != None:
        boosters = 0
        for date in dates:
            if vaccination_stats[country][date]['total_boosters'] != None:
                boosters += vaccination_stats[country][date]['total_boosters']
            if country not in perPop:
                perPop[country] = None
            if perPop[country] == None:
                perPop[country] = (boosters/populationData[country])*100
            if  perPop[country] == 0:
                perPop.pop(country,0)
perPop
# Out:
# {'Albania': 7.035146670119448,
#  'Anguilla': 12.69337564458548,
#  'Argentina': 28.216143214653496,
#  'Austria': 52.17091867455057,
#  'Azerbaijan': 19.83964573965151,
#  'Bahamas': 4.544366592846219,
#  'Bahrain': 53.721775588941036,
#  'Bangladesh': 0.760464451614214,
#  'Belgium': 56.569282856644485,
#  'Bermuda': 45.05588301607241,
#  'Bhutan': 45.12975564471354,
#  'Bolivia': 7.430234901923831,
#  'Bosnia and Herzegovina': 3.6930092954879292,
#  'Brazil': 22.088825563705637,
#  'Bulgaria': 8.864136189918142,
#  'Cambodia': 35.90026796216628,
#  'Canada': 40.76035352074634,
#  'Chile': 66.1729087254466,
#  'Colombia': 11.14750733797361,
#  'Costa Rica': 11.26831740081565,
#  'Cuba': 47.3474721374126,
#  'Curacao': 22.287891843347612,
#  'Cyprus': 45.122641288322264,
#  'Czechia': 35.007726289076224,
#  'Denmark': 61.354588115487296,
#  'Dominican Republic': 17.78815545272214,
#  'Ecuador': 14.568909813770675,
#  'El Salvador': 18.994354101234677,
# ...

# %%
#Q20: Among all the countries in the dataset, what is the rank of Canada's percentage of population boosted?
count = 0
for country in perPop:
    if perPop[country] != None:
        if perPop['Canada'] <= perPop[country]:
            count += 1
count
# Out:
# 38
